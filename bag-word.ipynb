# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 777.4 MB 5.4 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
# !pip install <model_s3_url> # tar.gz file e.g. from release notes like https://github.com/explosion/spacy-models/releases//tag/en_core_web_lg-2.3.1
# !pip install en_core_web_lg
import spacy
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: `pip install <model_s3_url> # tar.gz file e.g. from release notes like https://github.com/explosion/spacy-models/releases//tag/en_core_web_lg-2.3.1'
# ...

# %%
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
text = 'Texas is one of the biggest states by population and area in the United States. The state is on the south-central region of the country, and it is bordered by the Mexican Gulf to the southeast. Texas is surrounded by the Mexican states of Coahuila, Tamaulipas, Chihuahua, and Nuevo Leon to the southwestern side and numerous American states including Arkansas, Oklahoma, Louisiana, and New Mexico. The state has over 28,304,596 residents with its most populous city being Houston followed by San Francisco, Dallas-Fort Worth, and Greater Houston. Houston is the ranked fourth in the country while Austin is the second most highly populated state capital in the country. Texas is known as the "Lone Star State" and is famous for its BBQ, live music, hot temperatures, and more.'

# %%
doc = nlp(text)

# %%
doc
# Out:
# Texas is one of the biggest states by population and area in the United States. The state is on the south-central region of the country, and it is bordered by the Mexican Gulf to the southeast. Texas is surrounded by the Mexican states of Coahuila, Tamaulipas, Chihuahua, and Nuevo Leon to the southwestern side and numerous American states including Arkansas, Oklahoma, Louisiana, and New Mexico. The state has over 28,304,596 residents with its most populous city being Houston followed by San Francisco, Dallas-Fort Worth, and Greater Houston. Houston is the ranked fourth in the country while Austin is the second most highly populated state capital in the country. Texas is known as the "Lone Star State" and is famous for its BBQ, live music, hot temperatures, and more.

# %%
# Analyze syntax
tokens =[token for token in doc if not token.is_stop]
print("Without Stopowords:",tokens)
# Out:
# Without Stopowords: [Texas, biggest, states, population, area, United, States, ., state, south, -, central, region, country, ,, bordered, Mexican, Gulf, southeast, ., Texas, surrounded, Mexican, states, Coahuila, ,, Tamaulipas, ,, Chihuahua, ,, Nuevo, Leon, southwestern, numerous, American, states, including, Arkansas, ,, Oklahoma, ,, Louisiana, ,, New, Mexico, ., state, 28,304,596, residents, populous, city, Houston, followed, San, Francisco, ,, Dallas, -, Fort, Worth, ,, Greater, Houston, ., Houston, ranked, fourth, country, Austin, second, highly, populated, state, capital, country, ., Texas, known, ", Lone, Star, State, ", famous, BBQ, ,, live, music, ,, hot, temperatures, ,, .]
