# %%
Generated_text="Supervision challenge nasa How to Supervision your dog on daily and weekly walks. A good dog owner is a good life, as well as a good dog. There is some sense of the dog’s well being, and you need to take care of him. It’s hard to ignore the dog’s emotions that are just as important, unless it’s a very small dog, that."
Collected_text ="Many of NASA's contests also center on robotics. The Telerobotic Construction Challenge, scheduled for August 2007, requires a team of machines to assemble items with minimal human supervision. The idea is to let robots, instead of astronauts, build shelters and machinery on the moon and Mars. In the Regolith Excavation Challenge, set for May 2007, an autonomous machine will have to dig through 24 square meters of simulated moon rock. A separate Regolith Oxygen competition, scheduled for 2008, will be held for robots that can extract oxygen from the stones. Some contests will be held annually; others will be one-time events."
# Split the documents and create tokens
doc1_tokens=set(Generated_text.lower().split())
doc2_tokens=set(Collected_text.lower().split())

#Print the tokens
print(doc1_tokens ,doc2_tokens)


# Calculate the Jaccard Similarity
jaccard_similarity=  len(doc1_tokens.intersection(doc2_tokens))/len(doc1_tokens.union(doc2_tokens))

# Print the Jaccard Simialrity score
print("Similarity %:",jaccard_similarity*100)
# Out:
# {'just', 'being,', 'and', 'how', 'you', 'hard', 'unless', 'that.', 'to', 'life,', 'very', 'are', 'ignore', 'dog.', 'there', 'take', 'challenge', 'walks.', 'need', 'it’s', 'as', 'care', 'some', 'nasa', 'dog', 'owner', 'small', 'dog,', 'sense', 'a', 'well', 'weekly', 'him.', 'good', 'daily', 'is', 'emotions', 'of', 'the', 'that', 'your', 'supervision', 'important,', 'dog’s', 'on'} {'in', 'meters', 'oxygen', "nasa's", 'machines', 'through', '2008,', 'and', 'many', 'assemble', 'minimal', 'to', 'for', 'center', 'one-time', '2007,', 'scheduled', 'telerobotic', 'requires', 'idea', 'instead', 'robots', 'others', 'annually;', 'let', 'may', 'construction', 'from', 'mars.', 'competition,', 'some', 'can', 'moon', '24', 'astronauts,', 'simulated', 'be', 'challenge,', 'august', 'an', 'a', 'shelters', 'stones.', 'robotics.', 'items', 'with', 'autonomous', 'square', 'excavation', 'rock.', 'separate', 'held', 'of', 'build', 'extract', 'will', 'regolith', 'the', 'supervision.', 'human', 'contests', 't
# ...
