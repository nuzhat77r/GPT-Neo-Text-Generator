# %%
# !pip install transformers happytransformer
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 33.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 52.0 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 312 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 212 kB 68.4 MB/s
# ...
#      |████████████████████████████████| 134 kB 71.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 144 kB 57.1 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 48.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
from happytransformer import HappyGeneration

happy_gen = HappyGeneration("GPT-NEO", "EleutherAI/gpt-neo-125M")
# Out:
# Downloading:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/502M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# 03/08/2022 07:40:48 - INFO - happytransformer.happy_transformer -   Using model: cpu

# %%
happy_gen.train("train.csv")
# Out:
# 03/08/2022 07:47:11 - INFO - happytransformer.happy_transformer -   Preprocessing dataset...
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-6a97994b0b47e80b/0.0.0/08f6fb1dd2dab0a18ea441c359e1d63794ea8cb53e7863e6edf8fc5655e47ec4. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]
# 03/08/2022 07:47:12 - INFO - happytransformer.happy_transformer -   Training...
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1
#   Num Epochs = 3
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
# ...

# %%
from happytransformer import GENTrainArgs 

args = GENTrainArgs(learning_rate =1e-5, num_train_epochs = 1)
happy_gen.train("train.csv", args=args)
# Out:
# 03/08/2022 07:49:58 - INFO - happytransformer.happy_transformer -   Preprocessing dataset...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 03/08/2022 07:49:59 - INFO - happytransformer.happy_transformer -   Training...
# PyTorch: setting up devices
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1
#   Num Epochs = 1
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:00, Epoch 1/1]
#     </div>
# ...

# %%
from happytransformer import GENSettings

# %%
args = GENSettings(no_repeat_ngram_size=2)

# %%
top_k_sampling_settings = GENSettings(do_sample=True, early_stopping=False, top_k=90, temperature=0.7)

# %%
result = happy_gen.generate_text("Dyson’s laser-equipped vacuum is one of the latest examples of cleaning tech, products that are designed to make our household", args=top_k_sampling_settings)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result.text)
# Out:
# ’s appearance. In this year’s issue, the company announced its latest effort to make their technology more practical and affordable. The product is an “implementation-based” vacuum cleaner that uses lasers. It’s
