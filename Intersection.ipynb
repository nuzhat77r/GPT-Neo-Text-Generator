# %%
# documents

Generated_text ="Dyson’s laser-equipped vacuum designed to take that advantage as well and it will provide some comfort and ease of use at night without the expense of the batteries. Some people like not needing to charge when they re out of the office, Mr. Davis said. But we had a vacuum installed last weekend. Maybe a little bit harder to get your car out than it did with the ones in the car — so this one won't really make a difference. designed to take that advantage as well, and it will provide some comfort and ease of use at night without the expense of the batteries. Some people like not needing to charge when they're out of the office, Mr. Davis said. But we had a vacuum installed last weekend — maybe a little bit harder to get your car out than it did with the ones in the car — so this one won't really make a difference."
Collected_text ="Dyson’s laser-equipped vacuum is one of the latest examples of cleaning tech, products that are designed to make our household hygiene as painless and efficient as possible. It’s an increasingly important category of technology now that the pandemic has forced so many of us to spend lots of time at home, creating messes that never seem to go away"
# Split the documents and create tokens
doc1_tokens=set(Generated_text.lower().split())
doc2_tokens=set(Collected_text.lower().split())

#Print the tokens
print(doc1_tokens ,doc2_tokens)


# Calculate the Jaccard Similarity
jaccard_similarity=  len(doc1_tokens.intersection(doc2_tokens))/len(doc1_tokens.union(doc2_tokens))

# Print the Jaccard Simialrity score
print("Similarity %:",jaccard_similarity*100)
# Out:
# {'charge', 'installed', 'laser-equipped', 'of', 'at', 'had', 'in', 'when', 'ease', 'people', 'like', 'night', 'last', 'maybe', 'well', 'difference.', 'the', 'to', 'weekend', "won't", 'use', 'did', 'will', 'take', 'but', 'than', 'that', 'weekend.', 'as', 'designed', 'some', 'out', 'advantage', 'little', 'this', 'expense', 'without', 'your', 'a', 'vacuum', 're', 'we', 'batteries.', 'with', 'provide', 'well,', 'get', 'really', 'ones', 'dyson’s', "they're", 'harder', 'car', 'make', 'davis', 'not', 'office,', 'mr.', 'bit', 'so', 'one', 'and', '—', 'comfort', 'said.', 'needing', 'they', 'it'} {'is', 'us', 'away', 'laser-equipped', 'of', 'at', 'cleaning', 'are', 'messes', 'seem', 'latest', 'to', 'the', 'forced', 'our', 'that', 'lots', 'many', 'never', 'efficient', 'as', 'designed', 'has', 'important', 'tech,', 'spend', 'vacuum', 'now', 'painless', 'an', 'dyson’s', 'possible.', 'hygiene', 'examples', 'technology', 'make', 'time', 'increasingly', 'products', 'it’s', 'one', 'so', 'and', 'categ
# ...
