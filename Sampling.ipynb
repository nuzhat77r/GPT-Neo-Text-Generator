# %%
from random import sample

list1 = ['united', 'states', 'taliban', 'millions', 'afghans', 'largest', 'voluntary', 'refugee', 'repatriation', 'program', 'u.n', 'history', 'country', 'west', 'promises', 'security', 'development', 'violence', 'worse', 'afghans', 'promises', 'europe', 'boats', 'southeast', 'asia', 'australia', 'asylum', 'claims', 'western', 'countries', 'efforts', 'afghans', 'difficult', 'visas', 'fear', 'refugee', 'status']
print(sample(list1,3))
# Out:
# ['asia', 'claims', 'security']
